# %% [markdown]
# # Web Scraping With Beautiful Soup
# In this project, I'm going to collect data from the realtor website using Beautifulsoup library in Python. Create Data Frame and save as csv file/

# %%
#importing needed libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ## Collecting Data
# Here I'm going to use beautiful soup to collect data. After taking a closer look into HTML, I will be extracting following information: Address of the property,Price, Number of beds and baths, area of property, lot size and link to the property.

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 Safari/537.36",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8"}  
list_of_properties=[]
#creating loop to extract multiple pages of data 
for page in range(1,6):
    url="https://www.realtor.com/realestateandhomes-search/West-Palm-Beach_FL/beds-3/type-single-family-home/price-na-1000000/pg-"+ str(page)
    response = requests.get(url,headers=header)
    data = response.text
    soup = BeautifulSoup(data, "html.parser")
    properties=soup.find_all("li",{"class":"component_property-card"})
#collecting data
    for i in properties:
            address_elements = i.find_all("div", {"data-label":"pc-address"})
            addresses = [address.get_text(separator=" ").strip('Email agent').split(" | ")[0] for address in address_elements] # adding separator=" " in get_text to separate address from city 
            price_elements=i.find_all("span", {"data-label":"pc-price"})
            prices = [price.get_text(separator=" ").strip('From').split("|")[0] for price in price_elements if "$" in price.text]
            bedroom_elements = i.find_all("li", {"data-label": "pc-meta-beds"})
            beds = [bed.get_text(separator=" ").strip("bed").split("|")[0] for bed in bedroom_elements]
            baths_elements= i.find_all("li", {"data-label": "pc-meta-baths"})
            baths = [bath.get_text(separator=" ").strip('bath').split("|")[0] for bath in baths_elements]
            size_elements = i.find_all("li", {"data-label": "pc-meta-sqft"})
            sizes = [size.get_text(separator=" ").split("|")[0] for size in size_elements]
            area_lot_elements=i.find_all("li", {"data-label": "pc-meta-sqftlot"})
            area_lots = [area.get_text(separator=" ").strip('lot').split("|")[0] for area in area_lot_elements]
            url_elements=i.find_all("a", {"rel": "noopener"})
            urls=[x.get('href')  if 'http' in x.get('href') else 'https://www.realtor.com' + x.get('href') for x in url_elements]

            list_of_properties.append([addresses,prices,beds,baths,sizes,area_lots,urls])

# %% [markdown]
# ## Creating DataFrame

# %%
df = pd.DataFrame(list_of_properties, columns = ['Address', 'Price($)', 'Bed','Bath','Area(sqft)','Lot size','Link'])
#df=df[df['Address'].map(lambda x: len(x)) > 0]
df
# Out:
#                                                Address    Price($)   Bed  \
# 0    [7507 Pine Tree Ln ,  Lake Clarke Shores , FL ...  [$995,000]  [3 ]
# 1    [7442 Venetian Way ,  West Palm Beach , FL   3...  [$835,000]  [3 ]
# 2     [2620 Sandy Cay ,  West Palm Beach , FL   33411]  [$674,900]  [4 ]
# 3                                                   []          []    []
# 4    [2120 Chagall Cir ,  West Palm Beach , FL   33...  [$699,000]  [4 ]
# ..                                                 ...         ...   ...
# 250   [721 Maddock St ,  West Palm Beach , FL   33405]  [$379,900]  [3 ]
# 251  [5905 Snowdrop Way ,  West Palm Beach , FL   3...  [$449,500]  [4 ]
# 252  [212 S Robbins Dr ,  West Palm Beach , FL   33...  [$380,000]  [3 ]
# 253      [13706 52nd Ct N ,  The Acreage , FL   33411]  [$529,900]  [3 ]
# 254                                                 []          []    []
#
#        Bath    Area(sqft)       Lot size  \
# 0      [2 ]  [2,365 sqft]   [0.33 acre ]
# 1      [2 ]  [2,046 sqft]   [0.52 acre ]
# 2      [3 ]  [3,402 sqft]  [8,511 sqft ]
# 3        []            []             []
# 4    [2.5 ]  [2,762 sqft]  [5,698 sqft ]
# ..      ...           ...            ...
# 250    [1 ]  [1,036 sqft]  [5,446 sqft ]
# 251  [2.5 ]  [2,089 sqft]  [4,621 sqft ]
# 252    [2 ]  [1,275 sqft]  [7,200 sqft ]
# 253    [2 ]  [1,500 sqft]   [1.29 acre ]
# 254      []            []             []
#
#                                                   Link
# 0    [https://www.realtor.com/realestateandhomes-de...
# 1    [https://www.realtor.com/realestateandhomes-de...
# 2    [https://www.realtor.com/realestateandhomes-de...
# 3                                                   []
# 4    [https://www.realtor.com/realestateandhomes-de...
# ..                                                 ...
# 250  [https://www.realtor.com/realestateandhomes-de...
# 251  [https://www.realtor.com/realestateandhomes-de...
# 252  [https://www.realtor.com/realestateandhomes-de...
# 253  [https://www.realtor.com/realestateandhomes-de...
# 254                                                 []
#
# [255 rows x 7 columns]

# %% [markdown]
# ## Cleaning DataFrame

# %%
df=df.astype(str).replace({"\[":"", "\]":" ","\,":""}, regex=True)
new_df = df.apply(lambda x : x.str.strip("'$ "))
new_df=new_df.replace({'':np.nan})
new_df['Price($)'] = new_df['Price($)'].astype(float) 
new_df
# Out:
#                                                Address  Price($)  Bed Bath  \
# 0    7507 Pine Tree Ln   Lake Clarke Shores  FL   3...  995000.0    3    2
# 1      7442 Venetian Way   West Palm Beach  FL   33406  835000.0    3    2
# 2         2620 Sandy Cay   West Palm Beach  FL   33411  674900.0    4    3
# 3                                                  NaN       NaN  NaN  NaN
# 4       2120 Chagall Cir   West Palm Beach  FL   33409  699000.0    4  2.5
# ..                                                 ...       ...  ...  ...
# 250       721 Maddock St   West Palm Beach  FL   33405  379900.0    3    1
# 251    5905 Snowdrop Way   West Palm Beach  FL   33415  449500.0    4  2.5
# 252     212 S Robbins Dr   West Palm Beach  FL   33409  380000.0    3    2
# 253          13706 52nd Ct N   The Acreage  FL   33411  529900.0    3    2
# 254                                                NaN       NaN  NaN  NaN
#
#     Area(sqft)   Lot size                                               Link
# 0    2365 sqft  0.33 acre  https://www.realtor.com/realestateandhomes-det...
# 1    2046 sqft  0.52 acre  https://www.realtor.com/realestateandhomes-det...
# 2    3402 sqft  8511 sqft  https://www.realtor.com/realestateandhomes-det...
# 3          NaN        NaN                                                NaN
# 4    2762 sqft  5698 sqft  https://www.realtor.com/realestateandhomes-det...
# ..         ...        ...                                                ...
# 250  1036 sqft  5446 sqft  https://www.realtor.com/realestateandhomes-det...
# 251  2089 sqft  4621 sqft  https://www.realtor.com/realestateandhomes-det...
# 252  1275 sqft  7200 sqft  https://www.realtor.com/realestateandhomes-det...
# 253  1500 sqft  1.29 acre  https://www.realtor.com/realestateandhomes-det...
# 254        NaN        NaN                                                NaN
#
# [255 rows x 7 columns]

# %%
#cheking if there are missing values
new_df.isnull().sum()
# Out:
# Address       49
# Price($)      45
# Bed           45
# Bath          45
# Area(sqft)    46
# Lot size      83
# Link          45
# dtype: int64

# %%
#removing rows with missing values in adresses column 
new_df = new_df[~new_df.Address.isnull()]
# sorting data by Price 
new_df=new_df.sort_values(['Price($)'], ascending = [False]) 
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#                                                Address  Price($) Bed Bath  \
# 0    7507 Pine Tree Ln   Lake Clarke Shores  FL   3...  995000.0   3    2
# 1      7946 Via Villagio   West Palm Beach  FL   33412  995000.0   3    3
# 2        361 Colonial Rd   West Palm Beach  FL   33405  995000.0   3    2
# 3            11066 46th Pl N   The Acreage  FL   33411  975750.0   6    5
# 4    12837 Calais Cir   Palm Beach Gardens  FL   33410  969900.0   4    3
# ..                                                 ...       ...  ..  ...
# 201         1354 11th St   West Palm Beach  FL   33401  288900.0   3    1
# 202       128 Ethelyn Dr   West Palm Beach  FL   33415  280000.0   3    1
# 203     720 Division Ave   West Palm Beach  FL   33401  269999.0   3    2
# 204       5410 Helene Pl   West Palm Beach  FL   33407  265000.0   3    1
# 205         1016 21st St   West Palm Beach  FL   33407  180000.0   3    1
#
#     Area(sqft)   Lot size                                               Link
# 0    2365 sqft  0.33 acre  https://www.realtor.com/realestateandhomes-det...
# 1    2506 sqft  7000 sqft  https://www.realtor.com/realestateandhomes-det...
# 2    1456 sqft        NaN  https://www.realtor.com/realestateandhomes-det...
# 3    4123 sqft  1.25 acre  https://www.realtor.com/realestateandhomes-det...
# 4    2732 sqft  9234 sqft  https://www.realtor.com/realestateandhomes-det...
# ..         ...        ...                                                ...
# 201   792 sqft  6600 sqft  https://www.realtor.com/realestateandhomes-det...
# 202  1072 sqft  4750 sqft  https://www.realtor.com/realestateandhomes-det...
# 203  1110 sqft  3920 sqft  https://www.realtor.com/realestateandhomes-det...
# 204   914 sqft  6005 sqft  https://www.realtor.com/realestateandhomes-det...
# 205  1070 sqft  2793 sqft  https://www.realtor.com/realestateandhomes-det...
#
# [206 rows x 7 columns]

# %%
#cheking if we have duplicate data
print("There is {} duplicated values in data frame".format(new_df.duplicated().sum()))
# Out:
# There is 0 duplicated values in data frame

# %%
#saving to csv file
new_df.to_csv('RealEstate.csv', index=False)

# %%
# creating clikable links 
from IPython.display import HTML
df2=HTML(new_df.to_html(render_links=True, escape=False))
df2
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>